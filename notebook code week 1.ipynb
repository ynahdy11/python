# %%
import numpy as np

# %%
name = "yousef"
name
# Out:
# 'yousef'

# %%
'print(total)'
# Out:
# 'print(total)'

# %%
def f_to_c(degrees_f):
    return ((degrees_f-32)*5/9)

# %%
f_to_c(212)
# Out:
# 100.0

# %%
name = "supercalafragalisticexpialidocious"

# %%
name[-6:]
# Out:
# 'ocious'

# %%
phone='4163184513'

# %%
phone [0:3]
# Out:
# '416'

# %%
f'the year is {2026}'
# Out:
# 'the year is 2026'

# %%
def favorite_colour():
    colour=input('whats your favourite colour')
    return f" users favourite colour is {colour}"

# %%
favorite_colour
# Out:
# <function __main__.favorite_colour()>

# %%
def user_full_name ():
    first_name=input('enter your first name')
    last_name=input('enter your last name')
    return f"{first_name}{last_name}"

# %%
user_full_name()
# Out:
# 'yousef silim'

# %%
temp= 46

if temp <= 0:
    print("its freezing cold")
elif temp <= 15:
    print ("its cold")
elif temp <= 30:
    print("its hot")
elif temp <= 45:
    print("its very hot")
else:
    print("its extremely hot")
# Out:
# its extremely hot

# %%
# For testing purposes, we will write our code in the function
def anagram_checker(word_a, word_b):
  # Your code here
  word_a=set(word_a.lower())
  word_b=set(word_b.lower())
  return word_a == word_b


# Run your code to check using the words below:
anagram_checker("Silent", "listen")
# Out:
# True

# %%
anagram_checker("night", "Thing")
# Out:
# True

# %%
def anagram_checker(word_a, word_b, is_case_sensitive):
  # Modify your existing code here
    if is_case_sensitive == True:
        word_a=set(word_a)
        word_b=set(word_b)
        return word_a == word_b
    else: 
        return False
       

anagram_checker("Silent", "listen", True) # True
# Out:
# False
